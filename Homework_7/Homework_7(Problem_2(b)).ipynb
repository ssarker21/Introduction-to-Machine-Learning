# %% [markdown]
# <a href="https://colab.research.google.com/github/ssarker21/Introduction-to-Machine-Learning/blob/main/Homework_7(Problem_2(b)).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time


# ====================================================
# 1. Device Setup
# ====================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ====================================================
# 2. CIFAR-10: Transforms & Data Loaders
# ====================================================
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.4907, 0.4877, 0.4765],
        std=[0.2003, 0.1950, 0.2310]
    )
])

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=transform
)
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=64, shuffle=True, num_workers=0
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=transform
)
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=64, shuffle=False, num_workers=0
)

class_names = train_dataset.classes

# ====================================================
# 3. ResNet Building Blocks
# ====================================================
class BasicBlock(nn.Module):
    """
    Classic ResNet Basic Block:
    conv3x3 -> BN -> ReLU -> conv3x3 -> BN + skip connection
    If in/out dims differ, use a 1x1 conv in the skip path.
    """
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(
            in_channels, out_channels,
            kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)

        self.conv2 = nn.Conv2d(
            out_channels, out_channels,
            kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        # Skip / identity path
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            # 1x1 conv to match shape
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels,
                    kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        # Add skip connection
        out += self.shortcut(identity)
        out = F.relu(out)
        return out


class ResNet10(nn.Module):
    """
    ResNet-10 for CIFAR-10:
    - Initial conv
    - 4 stages with BasicBlocks
      blocks_per_stage = [2, 2, 3, 3] -> total = 10
    - Global average pooling + FC
    - Optional dropout before FC for regularization
    """
    def __init__(
        self,
        block=BasicBlock,
        num_blocks=[2, 2, 3, 3],
        num_classes=10,
        dropout_p=0.0
    ):
        super(ResNet10, self).__init__()

        self.in_channels = 16

        # Initial stem: 3x3 conv, 16 channels (no maxpool for CIFAR)
        self.conv1 = nn.Conv2d(
            3, 16, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(16)

        # Residual stages
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 128, num_blocks[3], stride=2)

        # Global Average Pooling + Fully Connected
        self.dropout = nn.Dropout(p=dropout_p)
        self.fc = nn.Linear(128 * block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        """
        Build one stage of the network with `num_blocks` residual blocks.
        First block may downsample using `stride`, rest use stride=1.
        """
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []

        for s in strides:
            layers.append(block(self.in_channels, out_channels, stride=s))
            self.in_channels = out_channels * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        # Initial conv + BN + ReLU
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)

        # Residual stages
        out = self.layer1(out)   # 32x32
        out = self.layer2(out)   # 16x16
        out = self.layer3(out)   # 8x8
        out = self.layer4(out)   # 4x4

        # Global average pool to 1x1
        out = F.adaptive_avg_pool2d(out, (1, 1))
        out = out.view(out.size(0), -1)   # (batch, 128)

        # Optional dropout regularization
        out = self.dropout(out)

        out = self.fc(out)
        return out


# ====================================================
# 4. Helper: Training + Evaluation Function
# ====================================================
def train_and_evaluate(
    exp_name,
    dropout_p=0.0,
    weight_decay=0.0,
    num_epochs=30,
    lr=0.0015
):
    print(f"\n\n========== Experiment: {exp_name} ==========")
    print(f"Dropout p = {dropout_p}, Weight Decay = {weight_decay}")

    model = ResNet10(dropout_p=dropout_p).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=weight_decay
    )

    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    start_time = time.time()

    for epoch in range(num_epochs):

        # ----- Training -----
        model.train()
        running_train_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        avg_train_loss = running_train_loss / len(train_loader)
        train_acc = correct_train / total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_acc)

        # ----- Testing -----
        model.eval()
        running_test_loss = 0.0
        correct_test = 0
        total_test = 0

        with torch.no_grad():
            for images, labels in test_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                running_test_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        avg_test_loss = running_test_loss / len(test_loader)
        test_acc = correct_test / total_test
        test_losses.append(avg_test_loss)
        test_accuracies.append(test_acc)

        print(f"\nEpoch {epoch+1}/{num_epochs} [{exp_name}]")
        print(f"  Train - Loss: {avg_train_loss:.4f}, Acc: {train_acc:.4f}")
        print(f"  Test  - Loss: {avg_test_loss:.4f}, Acc: {test_acc:.4f}")

    end_time = time.time()
    total_time = end_time - start_time

    # ---- Metrics Table ----
    print(f"\nEpoch-wise Test Metrics ({exp_name})")
    print("-" * 55)
    print(f"{'Epoch':>5} | {'Test Loss':>12} | {'Test Accuracy':>14}")
    print("-" * 55)
    for i, (ls, ac) in enumerate(zip(test_losses, test_accuracies), start=1):
        print(f"{i:5d} | {ls:12.4f} | {ac:14.4f}")
    print("-" * 55)

    # ---- Runtime Summary ----
    print(f"\nRuntime Summary ({exp_name})")
    print("-" * 48)
    print(f"{'Total Epochs':<25} | {num_epochs:18d}")
    print(f"{'Total Time (seconds)':<25} | {total_time:18.2f}")
    print(f"{'Time per Epoch (sec)':<25} | {total_time/num_epochs:18.2f}")
    print("-" * 48)

    return {
        "model": model,
        "train_losses": train_losses,
        "test_losses": test_losses,
        "train_acc": train_accuracies,
        "test_acc": test_accuracies,
        "time": total_time
    }


# ====================================================
# 5. Run 3 Experiments
#    1) Baseline (no reg)
#    2) Weight Decay = 0.001
#    3) Dropout p = 0.3
# ====================================================
histories = {}

# 1) Baseline
histories["baseline"] = train_and_evaluate(
    exp_name="Baseline (no regularization)",
    dropout_p=0.0,
    weight_decay=0.0,
    num_epochs=30
)

# 2) Weight Decay
histories["weight_decay_0.001"] = train_and_evaluate(
    exp_name="Weight Decay (lambda=0.001)",
    dropout_p=0.0,
    weight_decay=0.001,
    num_epochs=30
)

# 3) Dropout
histories["dropout_0.3"] = train_and_evaluate(
    exp_name="Dropout (p=0.3)",
    dropout_p=0.3,
    weight_decay=0.0,
    num_epochs=30
)

# ====================================================
# 6. Optional: Compare Test Accuracy Curves
# ====================================================
plt.figure(figsize=(8, 5))
plt.plot(histories["baseline"]["test_acc"], label="Baseline")
plt.plot(histories["weight_decay_0.001"]["test_acc"], label="Weight Decay λ=0.001")
plt.plot(histories["dropout_0.3"]["test_acc"], label="Dropout p=0.3")
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.title("ResNet-10: Regularization Comparison (Test Accuracy)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Using device: cuda
# 100%|██████████| 170M/170M [00:13<00:00, 12.6MB/s]
# ========== Experiment: Baseline (no regularization) ==========
# Dropout p = 0.0, Weight Decay = 0.0
#
# Epoch 1/30 [Baseline (no regularization)]
#   Train - Loss: 1.3747, Acc: 0.4950
#   Test  - Loss: 1.2195, Acc: 0.5670
#
# Epoch 2/30 [Baseline (no regularization)]
#   Train - Loss: 0.8728, Acc: 0.6925
#   Test  - Loss: 0.8429, Acc: 0.7057
#
# Epoch 3/30 [Baseline (no regularization)]
#   Train - Loss: 0.6792, Acc: 0.7627
#   Test  - Loss: 0.8054, Acc: 0.7303
#
# Epoch 4/30 [Baseline (no regularization)]
#   Train - Loss: 0.5645, Acc: 0.8030
#   Test  - Loss: 0.6549, Acc: 0.7716
#
# Epoch 5/30 [Baseline (no regularization)]
#   Train - Loss: 0.4757, Acc: 0.8336
#   Test  - Loss: 0.6120, Acc: 0.7928
#
# Epoch 6/30 [Baseline (no regularization)]
#   Train - Loss: 0.3978, Acc: 0.8615
#   Test  - Loss: 0.5740, Acc: 0.8060
#
# Epoch 7/30 [Baseline (no regularization)]
#   Train - Loss: 0.3287, Acc: 0.8837
#   Test  - Loss: 0.6287, Acc: 0.8007
#
# Epoch 8/30 [Baseline (no regularization)]
#   Train - Loss: 0.2734, Acc: 0.9027
#   Test  - Loss: 0.7295, Acc: 0.7875
#
# Epoch 9/30 [Baseline (no regularization)]
#   Train - Loss: 0.2183, Acc: 0.9225
#   Test  - Loss: 0.6425, Acc: 0.8095
#
# Epoch 10/30 [Baseline (no regularization)]
#   Train - Loss: 0.1784, Acc: 0.9348
#   Test  - Loss: 0.7245, Acc: 0.8031
#
# Epoch 11/30 [Baseline (no regularization)]
#   Train - Loss: 0.1414, Acc: 0.9505
#   Test  - Loss: 0.7783, Acc: 0.7950
#
# Epoch 12/30 [Baseline (no regularization)]
#   Train - Loss: 0.1226, Acc: 0.9566
#   Test  - Loss: 0.7975, Acc: 0.8034
#
# Epoch 13/30 [Baseline (no regularization)]
#   Train - Loss: 0.1046, Acc: 0.9620
#   Test  - Loss: 0.8449, Acc: 0.8016
#
# Epoch 14/30 [Baseline (no regularization)]
#   Train - Loss: 0.0880, Acc: 0.9693
#   Test  - Loss: 0.8790, Acc: 0.7926
#
# Epoch 15/30 [Baseline (no regularization)]
#   Train - Loss: 0.0836, Acc: 0.9709
#   Test  - Loss: 0.8817, Acc: 0.8059
#
# Epoch 16/30 [Baseline (no regularization)]
#   Train - Loss: 0.0742, Acc: 0.9742
#   Test  - Loss: 0.8915, Acc: 0.8038
#
# Epoch 17/30 [Baseline (no regularization)]
#   Train - Loss: 0.0690, Acc: 0.9757
#   Test  - Loss: 0.9519, Acc: 0.8048
#
# Epoch 18/30 [Baseline (no regularization)]
#   Train - Loss: 0.0664, Acc: 0.9763
#   Test  - Loss: 0.9092, Acc: 0.8084
#
# Epoch 19/30 [Baseline (no regularization)]
#   Train - Loss: 0.0583, Acc: 0.9796
#   Test  - Loss: 0.9149, Acc: 0.8104
#
# Epoch 20/30 [Baseline (no regularization)]
#   Train - Loss: 0.0584, Acc: 0.9792
#   Test  - Loss: 1.0120, Acc: 0.7973
#
# Epoch 21/30 [Baseline (no regularization)]
#   Train - Loss: 0.0501, Acc: 0.9828
#   Test  - Loss: 0.9838, Acc: 0.8113
#
# Epoch 22/30 [Baseline (no regularization)]
#   Train - Loss: 0.0481, Acc: 0.9834
#   Test  - Loss: 0.9793, Acc: 0.8138
#
# Epoch 23/30 [Baseline (no regularization)]
#   Train - Loss: 0.0493, Acc: 0.9830
#   Test  - Loss: 1.1217, Acc: 0.7922
#
# Epoch 24/30 [Baseline (no regularization)]
#   Train - Loss: 0.0428, Acc: 0.9851
#   Test  - Loss: 0.9660, Acc: 0.8169
#
# Epoch 25/30 [Baseline (no regularization)]
#   Train - Loss: 0.0430, Acc: 0.9852
#   Test  - Loss: 1.0152, Acc: 0.8064
#
# Epoch 26/30 [Baseline (no regularization)]
#   Train - Loss: 0.0461, Acc: 0.9839
#   Test  - Loss: 1.0320, Acc: 0.8061
#
# Epoch 27/30 [Baseline (no regularization)]
#   Train - Loss: 0.0421, Acc: 0.9853
#   Test  - Loss: 0.9932, Acc: 0.8110
#
# Epoch 28/30 [Baseline (no regularization)]
#   Train - Loss: 0.0354, Acc: 0.9882
#   Test  - Loss: 1.0725, Acc: 0.8081
#
# Epoch 29/30 [Baseline (no regularization)]
#   Train - Loss: 0.0455, Acc: 0.9839
#   Test  - Loss: 1.0965, Acc: 0.8064
#
# Epoch 30/30 [Baseline (no regularization)]
#   Train - Loss: 0.0355, Acc: 0.9875
#   Test  - Loss: 1.0726, Acc: 0.8092
#
# Epoch-wise Test Metrics (Baseline (no regularization))
# -------------------------------------------------------
# Epoch |    Test Loss |  Test Accuracy
# -------------------------------------------------------
#     1 |       1.2195 |         0.5670
#     2 |       0.8429 |         0.7057
#     3 |       0.8054 |         0.7303
#     4 |       0.6549 |         0.7716
#     5 |       0.6120 |         0.7928
#     6 |       0.5740 |         0.8060
#     7 |       0.6287 |         0.8007
#     8 |       0.7295 |         0.7875
#     9 |       0.6425 |         0.8095
#    10 |       0.7245 |         0.8031
#    11 |       0.7783 |         0.7950
#    12 |       0.7975 |         0.8034
#    13 |       0.8449 |         0.8016
#    14 |       0.8790 |         0.7926
#    15 |       0.8817 |         0.8059
#    16 |       0.8915 |         0.8038
#    17 |       0.9519 |         0.8048
#    18 |       0.9092 |         0.8084
#    19 |       0.9149 |         0.8104
#    20 |       1.0120 |         0.7973
#    21 |       0.9838 |         0.8113
#    22 |       0.9793 |         0.8138
#    23 |       1.1217 |         0.7922
#    24 |       0.9660 |         0.8169
#    25 |       1.0152 |         0.8064
#    26 |       1.0320 |         0.8061
#    27 |       0.9932 |         0.8110
#    28 |       1.0725 |         0.8081
#    29 |       1.0965 |         0.8064
#    30 |       1.0726 |         0.8092
# -------------------------------------------------------
#
# Runtime Summary (Baseline (no regularization))
# ------------------------------------------------
# Total Epochs              |                 30
# Total Time (seconds)      |             787.87
# Time per Epoch (sec)      |              26.26
# ------------------------------------------------
#
#
# ========== Experiment: Weight Decay (lambda=0.001) ==========
# Dropout p = 0.0, Weight Decay = 0.001
#
# Epoch 1/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 1.3695, Acc: 0.4982
#   Test  - Loss: 1.2072, Acc: 0.5724
#
# Epoch 2/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.9459, Acc: 0.6666
#   Test  - Loss: 0.9210, Acc: 0.6802
#
# Epoch 3/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.7846, Acc: 0.7274
#   Test  - Loss: 1.1943, Acc: 0.6287
#
# Epoch 4/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.6953, Acc: 0.7616
#   Test  - Loss: 0.8429, Acc: 0.7145
#
# Epoch 5/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.6382, Acc: 0.7794
#   Test  - Loss: 0.6879, Acc: 0.7645
#
# Epoch 6/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.5876, Acc: 0.8003
#   Test  - Loss: 0.7085, Acc: 0.7604
#
# Epoch 7/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.5561, Acc: 0.8100
#   Test  - Loss: 0.6730, Acc: 0.7712
#
# Epoch 8/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.5279, Acc: 0.8189
#   Test  - Loss: 0.7032, Acc: 0.7633
#
# Epoch 9/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4987, Acc: 0.8289
#   Test  - Loss: 0.6905, Acc: 0.7625
#
# Epoch 10/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4839, Acc: 0.8353
#   Test  - Loss: 0.7038, Acc: 0.7573
#
# Epoch 11/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4650, Acc: 0.8411
#   Test  - Loss: 0.6339, Acc: 0.7911
#
# Epoch 12/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4504, Acc: 0.8445
#   Test  - Loss: 0.6102, Acc: 0.7941
#
# Epoch 13/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4384, Acc: 0.8515
#   Test  - Loss: 0.5978, Acc: 0.7984
#
# Epoch 14/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4271, Acc: 0.8525
#   Test  - Loss: 0.5961, Acc: 0.8013
#
# Epoch 15/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4157, Acc: 0.8583
#   Test  - Loss: 0.6314, Acc: 0.7897
#
# Epoch 16/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.4085, Acc: 0.8596
#   Test  - Loss: 0.6016, Acc: 0.7969
#
# Epoch 17/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3968, Acc: 0.8649
#   Test  - Loss: 0.5917, Acc: 0.7977
#
# Epoch 18/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3948, Acc: 0.8648
#   Test  - Loss: 0.5444, Acc: 0.8172
#
# Epoch 19/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3838, Acc: 0.8686
#   Test  - Loss: 0.5830, Acc: 0.8053
#
# Epoch 20/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3764, Acc: 0.8709
#   Test  - Loss: 0.5993, Acc: 0.7950
#
# Epoch 21/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3749, Acc: 0.8716
#   Test  - Loss: 0.6188, Acc: 0.7972
#
# Epoch 22/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3690, Acc: 0.8749
#   Test  - Loss: 0.5796, Acc: 0.8080
#
# Epoch 23/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3643, Acc: 0.8747
#   Test  - Loss: 0.6270, Acc: 0.7907
#
# Epoch 24/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3572, Acc: 0.8767
#   Test  - Loss: 0.5690, Acc: 0.8094
#
# Epoch 25/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3562, Acc: 0.8778
#   Test  - Loss: 0.6376, Acc: 0.7873
#
# Epoch 26/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3501, Acc: 0.8807
#   Test  - Loss: 0.7119, Acc: 0.7784
#
# Epoch 27/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3481, Acc: 0.8817
#   Test  - Loss: 0.5779, Acc: 0.8139
#
# Epoch 28/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3458, Acc: 0.8807
#   Test  - Loss: 0.5676, Acc: 0.8114
#
# Epoch 29/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3352, Acc: 0.8834
#   Test  - Loss: 0.5672, Acc: 0.8082
#
# Epoch 30/30 [Weight Decay (lambda=0.001)]
#   Train - Loss: 0.3377, Acc: 0.8835
#   Test  - Loss: 0.5836, Acc: 0.8093
#
# Epoch-wise Test Metrics (Weight Decay (lambda=0.001))
# -------------------------------------------------------
# Epoch |    Test Loss |  Test Accuracy
# -------------------------------------------------------
#     1 |       1.2072 |         0.5724
#     2 |       0.9210 |         0.6802
#     3 |       1.1943 |         0.6287
#     4 |       0.8429 |         0.7145
#     5 |       0.6879 |         0.7645
#     6 |       0.7085 |         0.7604
#     7 |       0.6730 |         0.7712
#     8 |       0.7032 |         0.7633
#     9 |       0.6905 |         0.7625
#    10 |       0.7038 |         0.7573
#    11 |       0.6339 |         0.7911
#    12 |       0.6102 |         0.7941
#    13 |       0.5978 |         0.7984
#    14 |       0.5961 |         0.8013
#    15 |       0.6314 |         0.7897
#    16 |       0.6016 |         0.7969
#    17 |       0.5917 |         0.7977
#    18 |       0.5444 |         0.8172
#    19 |       0.5830 |         0.8053
#    20 |       0.5993 |         0.7950
#    21 |       0.6188 |         0.7972
#    22 |       0.5796 |         0.8080
#    23 |       0.6270 |         0.7907
#    24 |       0.5690 |         0.8094
#    25 |       0.6376 |         0.7873
#    26 |       0.7119 |         0.7784
#    27 |       0.5779 |         0.8139
#    28 |       0.5676 |         0.8114
#    29 |       0.5672 |         0.8082
#    30 |       0.5836 |         0.8093
# -------------------------------------------------------
#
# Runtime Summary (Weight Decay (lambda=0.001))
# ------------------------------------------------
# Total Epochs              |                 30
# Total Time (seconds)      |             815.38
# Time per Epoch (sec)      |              27.18
# ------------------------------------------------
#
#
# ========== Experiment: Dropout (p=0.3) ==========
# Dropout p = 0.3, Weight Decay = 0.0
#
# Epoch 1/30 [Dropout (p=0.3)]
#   Train - Loss: 1.3573, Acc: 0.5083
#   Test  - Loss: 1.0590, Acc: 0.6233
#
# Epoch 2/30 [Dropout (p=0.3)]
#   Train - Loss: 0.9247, Acc: 0.6756
#   Test  - Loss: 0.8025, Acc: 0.7194
#
# Epoch 3/30 [Dropout (p=0.3)]
#   Train - Loss: 0.7335, Acc: 0.7494
#   Test  - Loss: 0.7074, Acc: 0.7573
#
# Epoch 4/30 [Dropout (p=0.3)]
#   Train - Loss: 0.6154, Acc: 0.7893
#   Test  - Loss: 0.6837, Acc: 0.7679
#
# Epoch 5/30 [Dropout (p=0.3)]
#   Train - Loss: 0.5188, Acc: 0.8235
#   Test  - Loss: 0.6538, Acc: 0.7818
#
# Epoch 6/30 [Dropout (p=0.3)]
#   Train - Loss: 0.4466, Acc: 0.8471
#   Test  - Loss: 0.6578, Acc: 0.7857
#
# Epoch 7/30 [Dropout (p=0.3)]
#   Train - Loss: 0.3721, Acc: 0.8707
#   Test  - Loss: 0.6028, Acc: 0.8014
#
# Epoch 8/30 [Dropout (p=0.3)]
#   Train - Loss: 0.3226, Acc: 0.8890
#   Test  - Loss: 0.6242, Acc: 0.8090
#
# Epoch 9/30 [Dropout (p=0.3)]
#   Train - Loss: 0.2699, Acc: 0.9069
#   Test  - Loss: 0.6235, Acc: 0.8053
#
# Epoch 10/30 [Dropout (p=0.3)]
#   Train - Loss: 0.2240, Acc: 0.9234
#   Test  - Loss: 0.6220, Acc: 0.8173
#
# Epoch 11/30 [Dropout (p=0.3)]
#   Train - Loss: 0.1819, Acc: 0.9365
#   Test  - Loss: 0.7149, Acc: 0.8096
#
# Epoch 12/30 [Dropout (p=0.3)]
#   Train - Loss: 0.1573, Acc: 0.9452
#   Test  - Loss: 0.7306, Acc: 0.8112
#
# Epoch 13/30 [Dropout (p=0.3)]
#   Train - Loss: 0.1331, Acc: 0.9536
#   Test  - Loss: 0.8209, Acc: 0.8077
#
# Epoch 14/30 [Dropout (p=0.3)]
#   Train - Loss: 0.1198, Acc: 0.9586
#   Test  - Loss: 0.7747, Acc: 0.8125
#
# Epoch 15/30 [Dropout (p=0.3)]
#   Train - Loss: 0.1004, Acc: 0.9661
#   Test  - Loss: 0.7994, Acc: 0.8066
#
# Epoch 16/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0946, Acc: 0.9678
#   Test  - Loss: 0.8584, Acc: 0.8142
#
# Epoch 17/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0850, Acc: 0.9715
#   Test  - Loss: 0.8690, Acc: 0.8077
#
# Epoch 18/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0838, Acc: 0.9710
#   Test  - Loss: 0.8533, Acc: 0.8104
#
# Epoch 19/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0724, Acc: 0.9753
#   Test  - Loss: 0.9136, Acc: 0.8066
#
# Epoch 20/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0733, Acc: 0.9747
#   Test  - Loss: 0.9003, Acc: 0.8127
#
# Epoch 21/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0639, Acc: 0.9785
#   Test  - Loss: 0.9423, Acc: 0.8188
#
# Epoch 22/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0656, Acc: 0.9773
#   Test  - Loss: 1.0277, Acc: 0.8010
#
# Epoch 23/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0560, Acc: 0.9810
#   Test  - Loss: 0.9654, Acc: 0.8135
#
# Epoch 24/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0559, Acc: 0.9811
#   Test  - Loss: 0.9403, Acc: 0.8093
#
# Epoch 25/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0582, Acc: 0.9800
#   Test  - Loss: 0.9275, Acc: 0.8174
#
# Epoch 26/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0467, Acc: 0.9837
#   Test  - Loss: 1.0411, Acc: 0.8074
#
# Epoch 27/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0538, Acc: 0.9813
#   Test  - Loss: 0.9728, Acc: 0.8129
#
# Epoch 28/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0489, Acc: 0.9839
#   Test  - Loss: 0.9590, Acc: 0.8094
#
# Epoch 29/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0470, Acc: 0.9843
#   Test  - Loss: 1.0521, Acc: 0.8038
#
# Epoch 30/30 [Dropout (p=0.3)]
#   Train - Loss: 0.0415, Acc: 0.9862
#   Test  - Loss: 1.0836, Acc: 0.8045
#
# Epoch-wise Test Metrics (Dropout (p=0.3))
# -------------------------------------------------------
# Epoch |    Test Loss |  Test Accuracy
# -------------------------------------------------------
#     1 |       1.0590 |         0.6233
#     2 |       0.8025 |         0.7194
#     3 |       0.7074 |         0.7573
#     4 |       0.6837 |         0.7679
#     5 |       0.6538 |         0.7818
#     6 |       0.6578 |         0.7857
#     7 |       0.6028 |         0.8014
#     8 |       0.6242 |         0.8090
#     9 |       0.6235 |         0.8053
#    10 |       0.6220 |         0.8173
#    11 |       0.7149 |         0.8096
#    12 |       0.7306 |         0.8112
#    13 |       0.8209 |         0.8077
#    14 |       0.7747 |         0.8125
#    15 |       0.7994 |         0.8066
#    16 |       0.8584 |         0.8142
#    17 |       0.8690 |         0.8077
#    18 |       0.8533 |         0.8104
#    19 |       0.9136 |         0.8066
#    20 |       0.9003 |         0.8127
#    21 |       0.9423 |         0.8188
#    22 |       1.0277 |         0.8010
#    23 |       0.9654 |         0.8135
#    24 |       0.9403 |         0.8093
#    25 |       0.9275 |         0.8174
#    26 |       1.0411 |         0.8074
#    27 |       0.9728 |         0.8129
#    28 |       0.9590 |         0.8094
#    29 |       1.0521 |         0.8038
#    30 |       1.0836 |         0.8045
# -------------------------------------------------------
#
# Runtime Summary (Dropout (p=0.3))
# ------------------------------------------------
# Total Epochs              |                 30
# Total Time (seconds)      |             768.26
# Time per Epoch (sec)      |              25.61
# ------------------------------------------------
